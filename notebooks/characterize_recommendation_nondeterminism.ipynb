# %% [markdown]
# # Characterize recommendation nondeterminism
# We've noticed that the scores for our candidates are non-deterministic, and we'd like to characterize where that nondeterminism comes from in our algorithmic implementation.

# %%
import networkx as nx
import pandas as pd
import jsonlines
from collections import defaultdict
from os import listdir
from os.path import splitext

# %% [markdown]
# ## Read in the comparative runs

# %%
datapath = '../data/conference_rec_output'
prefixes = ['16May2024', '20May2024']
runs = defaultdict(dict)
for run in prefixes:
    for f in listdir(datapath):
        if run in f:
            fname = splitext('_'.join(f.split('_')[1:]))[0]
            if splitext(f)[1] == '.graphml':
                runs[run][fname] = nx.read_graphml(f'{datapath}/{f}')
            elif splitext(f)[1] == '.jsonl':
                with jsonlines.open(f'{datapath}/{f}') as reader:
                    runs[run][fname] = [obj for obj in reader]
            elif splitext(f)[1] == '.csv':
                runs[run][fname] = pd.read_csv(f'{datapath}/{f}', index_col=0)

# %% [markdown]
# ## Compare composite scores

# %%
all_composite = runs['16May2024']['composite_scores'].merge(runs['20May2024']['composite_scores'], left_index=True, right_index=True)

# %%
all_composite['difference'] = all_composite['composite_score_x'] - all_composite['composite_score_y']

# %%
print(f'The mean difference between scores across runs is {all_composite.difference.mean()}')
# Out:
# The mean difference between scores across runs is -1.25727481885282e-05

# %% [markdown]
# It's a small difference, but I believe it's larger than can be attributed to numerical overflow, so let's hunt down the source.

# %% [markdown]
# ## Compare individual scores
# Since dictionary insertion order is preserved now in Python, we can directly compare these two lists (because of how I iterated to produce them in the algorithm).

# %%
score_diffs = defaultdict(list)
for x, y in zip(runs['16May2024']['individual_component_scores'], runs['20May2024']['individual_component_scores']):
    for score_type in ['co_citation', 'co_author', 'topic', 'geography']:
        d = x[score_type] - y[score_type]
        score_diffs[score_type].append(d)
score_mean_diffs = {k: sum(v)/len(v) for k, v in score_diffs.items()}
score_mean_diffs
# Out:
# {'co_citation': -4.275195028600522e-05,
#  'co_author': -1.00389446458504e-05,
#  'topic': 0.0,
#  'geography': 0.0}

# %% [markdown]
# Topic modeling isn't the issue, which is good, because it means we correctly set the random seeds in our model instantiations. The randomness is coming from the co-networks, which means it's either the Louvain clustering, or the generation of the networks themselves.

# %% [markdown]
# ## Compare the co-citation and co-author networks
# First, let's see if the networks themselves are the same:
# ### Co-citation

# %%
nx.is_isomorphic(runs['16May2024']['co_citation_network'], runs['20May2024']['co_citation_network'])
# Out:
# True

# %%
nx.utils.graphs_equal(runs['16May2024']['co_citation_network'], runs['20May2024']['co_citation_network'])
# Out:
# False

# %%
nx.utils.nodes_equal(runs['16May2024']['co_citation_network'].nodes(data=True), runs['20May2024']['co_citation_network'].nodes(data=True))
# Out:
# True

# %%
nx.utils.edges_equal(runs['16May2024']['co_citation_network'].edges(data=True), runs['20May2024']['co_citation_network'].edges(data=True))
# Out:
# False

# %%
nx.utils.edges_equal(runs['16May2024']['co_citation_network'].edges, runs['20May2024']['co_citation_network'].edges)
# Out:
# True

# %% [markdown]
# Something about the edge attributes is different between the two graphs.

# %%
for e1, e2, attrs in runs['16May2024']['co_citation_network'].edges(data=True):
    matching_edge_attrs = runs['20May2024']['co_citation_network'].get_edge_data(e1, e2)
    if attrs != matching_edge_attrs:
        print('Edge attrs non-matching! For edge ', e1, e2)
        print(attrs, matching_edge_attrs)
# Out:
# Edge attrs non-matching! For edge  yang, l qiu, bs
# {'weight': 1} {'weight': 2}
# Edge attrs non-matching! For edge  sun, wq leopold, ac
# {'weight': 6} {'weight': 49}
# Edge attrs non-matching! For edge  sun, wq farrant, jm
# {'weight': 5} {'weight': 16}
# Edge attrs non-matching! For edge  sun, wq crowe, lm
# {'weight': 7} {'weight': 5}
# Edge attrs non-matching! For edge  sun, wq tsan, fy
# {'weight': 6} {'weight': 9}
# Edge attrs non-matching! For edge  come, d horbowicz, m
# {'weight': 10} {'weight': 4}
# Edge attrs non-matching! For edge  come, d pammenter, nw
# {'weight': 5} {'weight': 11}
# Edge attrs non-matching! For edge  come, d farrant, jm
# {'weight': 15} {'weight': 5}
# Edge attrs non-matching! For edge  come, d golovina, ea
# {'weight': 6} {'weight': 2}
# Edge attrs non-matching! For edge  come, d koster, kl
# {'weight': 1} {'weight': 5}
# Edge attrs non-matching! For edge  black, m hong, td
# {'weight': 8} {'weight': 1}
# Edge attrs non-matching! For edge  black, m bochicchio, a
# {'weight': 1} {'weight': 5}
# Edge attrs non-matching! For edge  black, m vazzana, c
# {'weight': 4} {'weight': 1}
# Edge attrs non-matching! For edge  black, m tetteroo, faa
# {'weight': 4} {'weight': 1}
# Edge attrs non-matching! For edge  black, m hay, fr
# {'weight': 1} {'weight': 3}
# Edge attrs non-matching! For edge  corbineau, f obendorf, rl
# {'weight': 10} {'weight': 37}
# Edge attrs non-matching! For edge  corbineau, f berjak, p
# {'weight': 11} {'weight': 19}
# Edge attrs non-matching! For edge  corbineau, f walters, c
# {'weight': 4} {'weight': 8}
# Edge attrs non-matching! For edge  corbineau, f kranner, i
# {'weight': 6} {'weight': 7}
# Edge attrs non-matching! For edge  corbineau, f koster, kl
# {'weight': 7} {'weight': 1}
# Edge attrs non-matching! For edge  corbineau, f hincha, dk
# {'weight': 1} {'weight': 2}
# Edge attrs non-matching! For edge  corbineau, f heyer, ag
# {'weight': 3} {'weight': 1}
# Edge attrs non-matching! For edge  hoekstra, fa vu, bl
# {'weight': 26} {'weight': 24}
# Edge attrs non-matching! For edge  hoekstra, fa karssen, cm
# {'weight': 2} {'weight': 26}
# Edge attrs non-matching! For edge  hoekstra, fa finch-savage, we
# {'weight': 1} {'weight': 6}
# Edge attrs non-matching! For edge  hoekstra, fa tsvetkova, nm
# {'weight': 8} {'weight': 1}
# Edge attrs non-matching! For edge  hoekstra, fa quartacci, mf
# {'weight': 2} {'weight': 3}
# Edge attrs non-matching! For edge  hoekstra, fa pammenter, n
# {'weight': 3} {'weight': 2}
# Edge attrs non-matching! For edge  hoekstra, fa sinniah, ur
# {'weight': 3} {'weight': 1}
# Edge attrs non-matching! For edge  hoekstra, fa smith, me
# {'weight': 2} {'weight': 3}
# Edge attrs non-matching! For edge  satour, p vu, bl
# {'weight': 18} {'weight': 26}
# Edge attrs non-matching! For edge  satour, p pritchard, hw
# {'weight': 6} {'weight': 1}
# Edge attrs non-matching! For edge  satour, p liu, j
# {'weight': 4} {'weight': 1}
# Edge attrs non-matching! For edge  satour, p rajjou, l
# {'weight': 1} {'weight': 6}
# Edge attrs non-matching! For edge  satour, p covarrubias, aa
# {'weight': 3} {'weight': 2}
# Edge attrs non-matching! For edge  leprince, o walters, c
# {'weight': 67} {'weight': 45}
# Edge attrs non-matching! For edge  leprince, o illing, n
# {'weight': 7} {'weight': 3}
# Edge attrs non-matching! For edge  leprince, o pammenter, nw
# {'weight': 53} {'weight': 8}
# Edge attrs non-matching! For edge  leprince, o ballesteros, d
# {'weight': 20} {'weight': 5}
# Edge attrs non-matching! For edge  leprince, o daws, mi
# {'weight': 10} {'weight': 17}
# Edge attrs non-matching! For edge  leprince, o pritchard, hw
# {'weight': 35} {'weight': 53}
# Edge attrs non-matching! For edge  leprince, o dekkers, bjw
# {'weight': 28} {'weight': 17}
# Edge attrs non-matching! For edge  leprince, o tablin, f
# {'weight': 1} {'weight': 4}
# Edge attrs non-matching! For edge  leprince, o quartacci, mf
# {'weight': 2} {'weight': 1}
# Edge attrs non-matching! For edge  buitink, j obendorf, rl
# {'weight': 29} {'weight': 18}
# Edge attrs non-matching! For edge  buitink, j wolkers, wf
# {'weight': 50} {'weight': 24}
# Edge attrs non-matching! For edge  buitink, j cushman, jc
# {'weight': 16} {'weight': 8}
# Edge attrs non-matching! For edge  buitink, j lin, tp
# {'weight': 10} {'weight': 7}
# Edge attrs non-matching! For edge  buitink, j vazquezramos, j
# {'weight': 1} {'weight': 2}
# Edge attrs non-matching! For edge  buitink, j mishler, bd
# {'weight': 7} {'weight': 3}
# Edge attrs non-matching! For edge  buitink, j marzalina, m
# {'weight': 3} {'weight': 2}
# Edge attrs non-matching! For edge  buitink, j oliver, ae
# {'weight': 13} {'weight': 10}
# Edge attrs non-matching! For edge  buitink, j maia, j
# {'weight': 38} {'weight': 44}
# Edge attrs non-matching! For edge  buitink, j costa, mcd
# {'weight': 41} {'weight': 5}
# Edge attrs non-matching! For edge  buitink, j wang, z
# {'weight': 2} {'weight': 1}
# Edge attrs non-matching! For edge  buitink, j hay, fr
# {'weight': 38} {'weight': 19}
# Edge attrs non-matching! For edge  buitink, j engelmann, f
# {'weight': 5} {'weight': 1}
# Edge attrs non-matching! For edge  buitink, j popova, av
# {'weight': 1} {'weight': 13}
# Edge attrs non-matching! For edge  bochicchio, a bewley, jd
# {'weight': 4} {'weight': 2}
# Edge attrs non-matching! For edge  bochicchio, a koster, kl
# {'weight': 2} {'weight': 1}
# Edge attrs non-matching! For edge  wolkers, wf tunnacliffe, a
# {'weight': 7} {'weight': 21}
# Edge attrs non-matching! For edge  wolkers, wf oldenhof, h
# {'weight': 9} {'weight': 18}
# Edge attrs non-matching! For edge  wolkers, wf oliver, ae
# {'weight': 28} {'weight': 7}
# Edge attrs non-matching! For edge  wolkers, wf vazzana, c
# {'weight': 2} {'weight': 7}
# Edge attrs non-matching! For edge  wolkers, wf acker, jp
# {'weight': 7} {'weight': 2}
# Edge attrs non-matching! For edge  wolkers, wf zhang, l
# {'weight': 3} {'weight': 2}
# Edge attrs non-matching! For edge  wolkers, wf engelmann, f
# {'weight': 4} {'weight': 2}
# Edge attrs non-matching! For edge  tetteroo, faa oldenhof, h
# {'weight': 4} {'weight': 1}
# Edge attrs non-matching! For edge  bewley, jd hilhorst, hwm
# {'weight': 8} {'weight': 13}
# Edge attrs non-matching! For edge  bewley, jd karsten, u
# {'weight': 1} {'weight': 2}
# Edge attrs non-matching! For edge  bewley, jd holzinger, a
# {'weight': 2} {'weight': 4}
# Edge attrs non-matching! For edge  bewley, jd beckett, rp
# {'weight': 3} {'weight': 2}
# Edge attrs non-matching! For edge  bewley, jd stark, lr
# {'weight': 2} {'weight': 4}
# Edge attrs non-matching! For edge  bewley, jd proctor, mcf
# {'weight': 3} {'weight': 2}
# Edge attrs non-matching! For edge  bewley, jd leopold, ac
# {'weight': 5} {'weight': 1}
# Edge attrs non-matching! For edge  bewley, jd horbowicz, m
# {'weight': 1} {'weight': 3}
# Edge attrs non-matching! For edge  bewley, jd bradford, kj
# {'weight': 4} {'weight': 1}
# Edge attrs non-matching! For edge  pammenter, nw illing, n
# {'weight': 7} {'weight': 3}
# Edge attrs non-matching! For edge  pammenter, nw bailly, c
# {'weight': 8} {'weight': 13}
# Edge attrs non-matching! For edge  pammenter, nw crowe, jh
# {'weight': 1} {'weight': 5}
# Edge attrs non-matching! For edge  pammenter, nw vertucci, cw
# {'weight': 7} {'weight': 25}
# Edge attrs non-matching! For edge  pammenter, nw walters, c
# {'weight': 104} {'weight': 37}
# Edge attrs non-matching! For edge  pammenter, nw bartels, d
# {'weight': 5} {'weight': 10}
# Edge attrs non-matching! For edge  pammenter, nw atherton, nm
# {'weight': 13} {'weight': 32}
# Edge attrs non-matching! For edge  pammenter, nw koster, kl
# {'weight': 5} {'weight': 15}
# Edge attrs non-matching! For edge  pammenter, nw mundree, sg
# {'weight': 1} {'weight': 8}
# Edge attrs non-matching! For edge  pammenter, nw ballesteros, d
# {'weight': 20} {'weight': 2}
# Edge attrs non-matching! For edge  pammenter, nw chmielarz, p
# {'weight': 7} {'weight': 14}
# Edge attrs non-matching! For edge  pammenter, nw pence, vc
# {'weight': 1} {'weight': 4}
# Edge attrs non-matching! For edge  pammenter, nw close, tj
# {'weight': 4} {'weight': 1}
# Edge attrs non-matching! For edge  pammenter, nw ligterink, w
# {'weight': 3} {'weight': 15}
# Edge attrs non-matching! For edge  pammenter, nw costa, mcd
# {'weight': 2} {'weight': 7}
# Edge attrs non-matching! For edge  pammenter, nw engelmann, f
# {'weight': 14} {'weight': 26}
# Edge attrs non-matching! For edge  pammenter, nw heyer, ag
# {'weight': 4} {'weight': 5}
# Edge attrs non-matching! For edge  pammenter, nw ellis, rh
# {'weight': 3} {'weight': 5}
# Edge attrs non-matching! For edge  pammenter, nw cooper, k
# {'weight': 9} {'weight': 10}
# Edge attrs non-matching! For edge  berjak, p farrant, j
# {'weight': 10} {'weight': 5}
# Edge attrs non-matching! For edge  berjak, p bradford, kj
# {'weight': 4} {'weight': 22}
# Edge attrs non-matching! For edge  berjak, p walters, c
# {'weight': 37} {'weight': 106}
# Edge attrs non-matching! For edge  berjak, p probert, rj
# {'weight': 8} {'weight': 1}
# Edge attrs non-matching! For edge  berjak, p chmielarz, p
# {'weight': 15} {'weight': 8}
# Edge attrs non-matching! For edge  berjak, p close, tj
# {'weight': 1} {'weight': 6}
# Edge attrs non-matching! For edge  berjak, p song, sq
# {'weight': 13} {'weight': 65}
# Edge attrs non-matching! For edge  berjak, p hincha, dk
# {'weight': 1} {'weight': 2}
# Edge attrs non-matching! For edge  berjak, p oliver, ae
# {'weight': 1} {'weight': 2}
# Edge attrs non-matching! For edge  berjak, p navari-izzo, f
# {'weight': 2} {'weight': 5}
# Edge attrs non-matching! For edge  berjak, p kranner, i
# {'weight': 2} {'weight': 7}
# Edge attrs non-matching! For edge  berjak, p gorecki, rj
# {'weight': 3} {'weight': 4}
# Edge attrs non-matching! For edge  bartels, d mundree, sg
# {'weight': 40} {'weight': 67}
# Edge attrs non-matching! For edge  bartels, d phillips, j
# {'weight': 70} {'weight': 29}
# Edge attrs non-matching! For edge  bartels, d cuming, ac
# {'weight': 3} {'weight': 11}
# Edge attrs non-matching! For edge  bartels, d reski, r
# {'weight': 4} {'weight': 5}
# Edge attrs non-matching! For edge  bartels, d crowe, jh
# {'weight': 6} {'weight': 9}
# Edge attrs non-matching! For edge  bartels, d koornneef, m
# {'weight': 1} {'weight': 7}
# Edge attrs non-matching! For edge  bartels, d koster, kl
# {'weight': 11} {'weight': 16}
# Edge attrs non-matching! For edge  bartels, d jordano, j
# {'weight': 8} {'weight': 16}
# Edge attrs non-matching! For edge  bartels, d lehner, a
# {'weight': 1} {'weight': 7}
# Edge attrs non-matching! For edge  bartels, d driouich, a
# {'weight': 45} {'weight': 97}
# Edge attrs non-matching! For edge  bartels, d garcia-plazaola, ji
# {'weight': 2} {'weight': 29}
# Edge attrs non-matching! For edge  bartels, d cushman, jc
# {'weight': 28} {'weight': 53}
# Edge attrs non-matching! For edge  bartels, d cooper, k
# {'weight': 20} {'weight': 33}
# Edge attrs non-matching! For edge  bartels, d ligterink, w
# {'weight': 19} {'weight': 37}
# Edge attrs non-matching! For edge  bartels, d costa, mcd
# {'weight': 23} {'weight': 39}
# Edge attrs non-matching! For edge  bartels, d zhang, l
# {'weight': 1} {'weight': 5}
# Edge attrs non-matching! For edge  bartels, d heyer, ag
# {'weight': 1} {'weight': 5}
# Edge attrs non-matching! For edge  bartels, d prieto-dapena, p
# {'weight': 7} {'weight': 1}
# Edge attrs non-matching! For edge  bartels, d braga, mr
# {'weight': 3} {'weight': 18}
# Edge attrs non-matching! For edge  bartels, d del campo, em
# {'weight': 3} {'weight': 16}
# Edge attrs non-matching! For edge  bartels, d barreno, e
# {'weight': 7} {'weight': 15}
# Edge attrs non-matching! For edge  bartels, d hedley, cl
# {'weight': 2} {'weight': 3}
# Edge attrs non-matching! For edge  bartels, d li, xs
# {'weight': 12} {'weight': 6}
# Edge attrs non-matching! For edge  bartels, d georgieva, k
# {'weight': 9} {'weight': 46}
# Edge attrs non-matching! For edge  vertucci, cw obendorf, rl
# {'weight': 2} {'weight': 1}
# Edge attrs non-matching! For edge  vertucci, cw koster, kl
# {'weight': 2} {'weight': 5}
# Edge attrs non-matching! For edge  vertucci, cw atherton, nm
# {'weight': 3} {'weight': 5}
# Edge attrs non-matching! For edge  bradford, kj walters, c
# {'weight': 9} {'weight': 10}
# Edge attrs non-matching! For edge  bradford, kj leopold, ac
# {'weight': 19} {'weight': 1}
# Edge attrs non-matching! For edge  bradford, kj obendorf, rl
# {'weight': 5} {'weight': 30}
# Edge attrs non-matching! For edge  bradford, kj koster, kl
# {'weight': 2} {'weight': 1}
# Edge attrs non-matching! For edge  farrant, jm wood, aj
# {'weight': 42} {'weight': 3}
# Edge attrs non-matching! For edge  farrant, jm deng, x
# {'weight': 85} {'weight': 47}
# Edge attrs non-matching! For edge  farrant, jm farrant, j
# {'weight': 25} {'weight': 95}
# Edge attrs non-matching! For edge  farrant, jm jordano, j
# {'weight': 13} {'weight': 5}
# Edge attrs non-matching! For edge  farrant, jm gaff, df
# {'weight': 22} {'weight': 96}
# Edge attrs non-matching! For edge  farrant, jm golovina, ea
# {'weight': 24} {'weight': 22}
# Edge attrs non-matching! For edge  farrant, jm bailly, c
# {'weight': 16} {'weight': 7}
# Edge attrs non-matching! For edge  farrant, jm moore, jp
# {'weight': 141} {'weight': 56}
# Edge attrs non-matching! For edge  farrant, jm horbowicz, m
# {'weight': 8} {'weight': 1}
# Edge attrs non-matching! For edge  farrant, jm crowe, jh
# {'weight': 3} {'weight': 1}
# Edge attrs non-matching! For edge  farrant, jm greenwood, jl
# {'weight': 6} {'weight': 18}
# Edge attrs non-matching! For edge  farrant, jm catala, m
# {'weight': 4} {'weight': 2}
# Edge attrs non-matching! For edge  farrant, jm neuner, g
# {'weight': 8} {'weight': 4}
# Edge attrs non-matching! For edge  farrant, jm djilianov, d
# {'weight': 43} {'weight': 66}
# Edge attrs non-matching! For edge  farrant, jm duckett, jg
# {'weight': 10} {'weight': 3}
# Edge attrs non-matching! For edge  farrant, jm gasulla, f
# {'weight': 26} {'weight': 16}
# Edge attrs non-matching! For edge  farrant, jm giarola, v
# {'weight': 54} {'weight': 74}
# Edge attrs non-matching! For edge  farrant, jm gauslaa, y
# {'weight': 1} {'weight': 2}
# Edge attrs non-matching! For edge  farrant, jm zhang, dy
# {'weight': 6} {'weight': 1}
# Edge attrs non-matching! For edge  farrant, jm toneva, v
# {'weight': 34} {'weight': 17}
# Edge attrs non-matching! For edge  farrant, jm hilhorst, hwm
# {'weight': 110} {'weight': 47}
# Edge attrs non-matching! For edge  farrant, jm sakurai, m
# {'weight': 1} {'weight': 2}
# Edge attrs non-matching! For edge  farrant, jm potts, m
# {'weight': 3} {'weight': 1}
# Edge attrs non-matching! For edge  farrant, jm helm, rf
# {'weight': 1} {'weight': 2}
# Edge attrs non-matching! For edge  farrant, jm mladenov, p
# {'weight': 16} {'weight': 23}
# Edge attrs non-matching! For edge  farrant, jm dekkers, bjw
# {'weight': 5} {'weight': 11}
# Edge attrs non-matching! For edge  farrant, jm wang, t
# {'weight': 8} {'weight': 2}
# Edge attrs non-matching! For edge  farrant, jm ratajczak, e
# {'weight': 4} {'weight': 1}
# Edge attrs non-matching! For edge  farrant, jm jiang, cz
# {'weight': 24} {'weight': 21}
# Edge attrs non-matching! For edge  farrant, jm wang, h
# {'weight': 7} {'weight': 9}
# Edge attrs non-matching! For edge  farrant, jm pages, m
# {'weight': 1} {'weight': 2}
# Edge attrs non-matching! For edge  probert, rj hill, lm
# {'weight': 2} {'weight': 1}
# Edge attrs non-matching! For edge  karssen, cm kamada, h
# {'weight': 1} {'weight': 3}
# Edge attrs non-matching! For edge  obendorf, rl lin, tp
# {'weight': 16} {'weight': 11}
# Edge attrs non-matching! For edge  obendorf, rl gorecki, rj
# {'weight': 103} {'weight': 131}
# Edge attrs non-matching! For edge  obendorf, rl walters, c
# {'weight': 1} {'weight': 8}
# Edge attrs non-matching! For edge  obendorf, rl richter, a
# {'weight': 17} {'weight': 39}
# Edge attrs non-matching! For edge  obendorf, rl hincha, dk
# {'weight': 4} {'weight': 12}
# Edge attrs non-matching! For edge  obendorf, rl wang, z
# {'weight': 6} {'weight': 2}
# Edge attrs non-matching! For edge  obendorf, rl deng, x
# {'weight': 2} {'weight': 6}
# Edge attrs non-matching! For edge  obendorf, rl phillips, j
# {'weight': 2} {'weight': 6}
# Edge attrs non-matching! For edge  obendorf, rl rafudeen, ms
# {'weight': 2} {'weight': 10}
# Edge attrs non-matching! For edge  leopold, ac gaff, df
# {'weight': 1} {'weight': 2}
# Edge attrs non-matching! For edge  leopold, ac koster, kl
# {'weight': 17} {'weight': 13}
# Edge attrs non-matching! For edge  koster, kl cushman, jc
# {'weight': 2} {'weight': 9}
# Edge attrs non-matching! For edge  koster, kl crowe, jh
# {'weight': 3} {'weight': 9}
# Edge attrs non-matching! For edge  koster, kl proctor, mcf
# {'weight': 3} {'weight': 2}
# Edge attrs non-matching! For edge  koster, kl reski, r
# {'weight': 3} {'weight': 6}
# Edge attrs non-matching! For edge  koster, kl cuming, ac
# {'weight': 2} {'weight': 7}
# Edge attrs non-matching! For edge  koster, kl quatrano, rs
# {'weight': 7} {'weight': 1}
# Edge attrs non-matching! For edge  koster, kl sakata, y
# {'weight': 6} {'weight': 3}
# Edge attrs non-matching! For edge  iturriaga, g avelange-macherel, mh
# {'weight': 2} {'weight': 1}
# Edge attrs non-matching! For edge  salamini, f whittaker, a
# {'weight': 1} {'weight': 6}
# Edge attrs non-matching! For edge  salamini, f mishler, bd
# {'weight': 1} {'weight': 8}
# Edge attrs non-matching! For edge  salamini, f phillips, j
# {'weight': 13} {'weight': 18}
# Edge attrs non-matching! For edge  salamini, f frank, w
# {'weight': 3} {'weight': 8}
# Edge attrs non-matching! For edge  vazzana, c tuba, z
# {'weight': 8} {'weight': 4}
# Edge attrs non-matching! For edge  vazzana, c mundree, s
# {'weight': 6} {'weight': 4}
# Edge attrs non-matching! For edge  vazzana, c hartung, w
# {'weight': 1} {'weight': 2}
# Edge attrs non-matching! For edge  finch-savage, we atherton, nm
# {'weight': 13} {'weight': 4}
# Edge attrs non-matching! For edge  finch-savage, we khoo, kc
# {'weight': 5} {'weight': 4}
# Edge attrs non-matching! For edge  finch-savage, we tsan, fy
# {'weight': 5} {'weight': 4}
# Edge attrs non-matching! For edge  finch-savage, we almoguera, c
# {'weight': 1} {'weight': 2}
# Edge attrs non-matching! For edge  finch-savage, we scott, p
# {'weight': 2} {'weight': 1}
# Edge attrs non-matching! For edge  wesley-smith, j vazquezramos, j
# {'weight': 2} {'weight': 1}
# Edge attrs non-matching! For edge  walters, c garcia-plazaola, ji
# {'weight': 10} {'weight': 1}
# Edge attrs non-matching! For edge  walters, c hill, lm
# {'weight': 19} {'weight': 27}
# Edge attrs non-matching! For edge  walters, c song, sq
# {'weight': 13} {'weight': 15}
# Edge attrs non-matching! For edge  walters, c hincha, dk
# {'weight': 1} {'weight': 10}
# Edge attrs non-matching! For edge  walters, c oliver, ae
# {'weight': 1} {'weight': 2}
# Edge attrs non-matching! For edge  walters, c proctor, mcf
# {'weight': 1} {'weight': 2}
# Edge attrs non-matching! For edge  walters, c kranner, i
# {'weight': 3} {'weight': 12}
# Edge attrs non-matching! For edge  walters, c rafudeen, ms
# {'weight': 1} {'weight': 2}
# Edge attrs non-matching! For edge  walters, c dixon, kw
# {'weight': 1} {'weight': 6}
# Edge attrs non-matching! For edge  ellis, rh hilhorst, hwm
# {'weight': 2} {'weight': 1}
# Edge attrs non-matching! For edge  ellis, rh chmielarz, p
# {'weight': 1} {'weight': 4}
# Edge attrs non-matching! For edge  ellis, rh lehner, a
# {'weight': 2} {'weight': 3}
# Edge attrs non-matching! For edge  hay, fr vu, bl
# {'weight': 2} {'weight': 5}
# Edge attrs non-matching! For edge  pritchard, hw laza, jm
# {'weight': 8} {'weight': 1}
# Edge attrs non-matching! For edge  pritchard, hw michalak, m
# {'weight': 10} {'weight': 1}
# Edge attrs non-matching! For edge  pritchard, hw daws, mi
# {'weight': 29} {'weight': 68}
# Edge attrs non-matching! For edge  pritchard, hw williams, b
# {'weight': 2} {'weight': 1}
# Edge attrs non-matching! For edge  pritchard, hw wang, t
# {'weight': 1} {'weight': 2}
# Edge attrs non-matching! For edge  pritchard, hw fu, jr
# {'weight': 2} {'weight': 1}
# Edge attrs non-matching! For edge  pritchard, hw baskin, cc
# {'weight': 33} {'weight': 21}
# Edge attrs non-matching! For edge  pritchard, hw tan, yh
# {'weight': 4} {'weight': 14}
# Edge attrs non-matching! For edge  pritchard, hw zhang, j
# {'weight': 4} {'weight': 1}
# Edge attrs non-matching! For edge  pritchard, hw kalemba, em
# {'weight': 9} {'weight': 3}
# Edge attrs non-matching! For edge  horbowicz, m crowe, jh
# {'weight': 3} {'weight': 2}
# Edge attrs non-matching! For edge  horbowicz, m lahuta, lb
# {'weight': 41} {'weight': 126}
# Edge attrs non-matching! For edge  horbowicz, m zuther, e
# {'weight': 4} {'weight': 3}
# Edge attrs non-matching! For edge  horbowicz, m koornneef, m
# {'weight': 7} {'weight': 3}
# Edge attrs non-matching! For edge  horbowicz, m chien, ct
# {'weight': 6} {'weight': 4}
# Edge attrs non-matching! For edge  horbowicz, m deng, x
# {'weight': 3} {'weight': 1}
# Edge attrs non-matching! For edge  horbowicz, m golovina, ea
# {'weight': 4} {'weight': 2}
# Edge attrs non-matching! For edge  koornneef, m golovina, ea
# {'weight': 3} {'weight': 2}
# Edge attrs non-matching! For edge  koornneef, m heyer, ag
# {'weight': 3} {'weight': 4}
# Edge attrs non-matching! For edge  liu, y blomstedt, ck
# {'weight': 1} {'weight': 2}
# Edge attrs non-matching! For edge  liu, y pages, m
# {'weight': 4} {'weight': 3}
# Edge attrs non-matching! For edge  liu, y hundertmark, m
# {'weight': 3} {'weight': 5}
# Edge attrs non-matching! For edge  liu, y liu, x
# {'weight': 6} {'weight': 2}
# Edge attrs non-matching! For edge  liu, y takezawa, d
# {'weight': 2} {'weight': 3}
# Edge attrs non-matching! For edge  liu, y djilianov, d
# {'weight': 4} {'weight': 2}
# Edge attrs non-matching! For edge  liu, y vanburen, r
# {'weight': 4} {'weight': 1}
# Edge attrs non-matching! For edge  avelange-macherel, mh clegg, js
# {'weight': 1} {'weight': 7}
# Edge attrs non-matching! For edge  avelange-macherel, mh boschetti, c
# {'weight': 1} {'weight': 3}
# Edge attrs non-matching! For edge  lindsey, gg farrant, j
# {'weight': 4} {'weight': 1}
# Edge attrs non-matching! For edge  lindsey, gg nakahara, y
# {'weight': 1} {'weight': 2}
# Edge attrs non-matching! For edge  macherel, d hincha, dk
# {'weight': 12} {'weight': 30}
# Edge attrs non-matching! For edge  cushman, jc lin, tp
# {'weight': 8} {'weight': 6}
# Edge attrs non-matching! For edge  cushman, jc yobi, a
# {'weight': 18} {'weight': 3}
# Edge attrs non-matching! For edge  cushman, jc xu, wx
# {'weight': 7} {'weight': 2}
# Edge attrs non-matching! For edge  cushman, jc mundree, sg
# {'weight': 2} {'weight': 7}
# Edge attrs non-matching! For edge  cushman, jc georgieva, k
# {'weight': 2} {'weight': 4}
# Edge attrs non-matching! For edge  cushman, jc driouich, a
# {'weight': 5} {'weight': 11}
# Edge attrs non-matching! For edge  cushman, jc wang, z
# {'weight': 4} {'weight': 2}
# Edge attrs non-matching! For edge  tunnacliffe, a burnell, am
# {'weight': 24} {'weight': 49}
# Edge attrs non-matching! For edge  tunnacliffe, a eroglu, a
# {'weight': 2} {'weight': 7}
# Edge attrs non-matching! For edge  tunnacliffe, a ricci, c
# {'weight': 18} {'weight': 39}
# Edge attrs non-matching! For edge  tunnacliffe, a toner, m
# {'weight': 1} {'weight': 16}
# Edge attrs non-matching! For edge  tunnacliffe, a melone, g
# {'weight': 10} {'weight': 6}
# Edge attrs non-matching! For edge  tunnacliffe, a heyer, ag
# {'weight': 9} {'weight': 2}
# Edge attrs non-matching! For edge  tunnacliffe, a pielak, gj
# {'weight': 1} {'weight': 4}
# Edge attrs non-matching! For edge  tunnacliffe, a boothby, tc
# {'weight': 1} {'weight': 8}
# Edge attrs non-matching! For edge  tunnacliffe, a fontaneto, d
# {'weight': 16} {'weight': 2}
# Edge attrs non-matching! For edge  tunnacliffe, a manzanera, m
# {'weight': 25} {'weight': 19}
# Edge attrs non-matching! For edge  tunnacliffe, a kurzchalia, tv
# {'weight': 2} {'weight': 6}
# Edge attrs non-matching! For edge  tunnacliffe, a holmstrup, m
# {'weight': 7} {'weight': 20}
# Edge attrs non-matching! For edge  tunnacliffe, a loeschcke, v
# {'weight': 2} {'weight': 10}
# Edge attrs non-matching! For edge  tunnacliffe, a clark, ms
# {'weight': 9} {'weight': 11}
# Edge attrs non-matching! For edge  tunnacliffe, a popova, av
# {'weight': 11} {'weight': 1}
# Edge attrs non-matching! For edge  tunnacliffe, a chakrabortee, s
# {'weight': 4} {'weight': 17}
# Edge attrs non-matching! For edge  tunnacliffe, a wang, z
# {'weight': 5} {'weight': 8}
# Edge attrs non-matching! For edge  tunnacliffe, a wang, l
# {'weight': 4} {'weight': 1}
# Edge attrs non-matching! For edge  tunnacliffe, a wang, b
# {'weight': 1} {'weight': 2}
# Edge attrs non-matching! For edge  lin, tp zhang, l
# {'weight': 2} {'weight': 1}
# Edge attrs non-matching! For edge  golovina, ea crowe, jh
# {'weight': 28} {'weight': 10}
# Edge attrs non-matching! For edge  holmstrup, m somme, l
# {'weight': 4} {'weight': 19}
# Edge attrs non-matching! For edge  holmstrup, m block, w
# {'weight': 5} {'weight': 7}
# Edge attrs non-matching! For edge  holmstrup, m lee, re
# {'weight': 19} {'weight': 55}
# Edge attrs non-matching! For edge  holmstrup, m loeschcke, v
# {'weight': 17} {'weight': 30}
# Edge attrs non-matching! For edge  holmstrup, m overgaard, j
# {'weight': 25} {'weight': 11}
# Edge attrs non-matching! For edge  holmstrup, m burnell, am
# {'weight': 1} {'weight': 3}
# Edge attrs non-matching! For edge  holmstrup, m reinhardt, r
# {'weight': 6} {'weight': 2}
# Edge attrs non-matching! For edge  holmstrup, m clark, ms
# {'weight': 12} {'weight': 22}
# Edge attrs non-matching! For edge  holmstrup, m sorensen, jg
# {'weight': 30} {'weight': 41}
# Edge attrs non-matching! For edge  hoffmann, aa parkash, r
# {'weight': 75} {'weight': 62}
# Edge attrs non-matching! For edge  hoffmann, aa kellermann, v
# {'weight': 19} {'weight': 4}
# Edge attrs non-matching! For edge  hoffmann, aa ramniwas, s
# {'weight': 1} {'weight': 8}
# Edge attrs non-matching! For edge  hoffmann, aa sgro, cm
# {'weight': 1} {'weight': 22}
# Edge attrs non-matching! For edge  hoffmann, aa klok, cj
# {'weight': 14} {'weight': 11}
# Edge attrs non-matching! For edge  hamill, jd gaff, df
# {'weight': 41} {'weight': 82}
# Edge attrs non-matching! For edge  hamill, jd farrant, j
# {'weight': 4} {'weight': 8}
# Edge attrs non-matching! For edge  hamill, jd deng, x
# {'weight': 14} {'weight': 10}
# Edge attrs non-matching! For edge  hamill, jd gasulla, f
# {'weight': 12} {'weight': 10}
# Edge attrs non-matching! For edge  hamill, jd giarola, v
# {'weight': 1} {'weight': 6}
# Edge attrs non-matching! For edge  hamill, jd hilhorst, hwm
# {'weight': 3} {'weight': 2}
# Edge attrs non-matching! For edge  hamill, jd moore, jp
# {'weight': 6} {'weight': 3}
# Edge attrs non-matching! For edge  hamill, jd djilianov, d
# {'weight': 2} {'weight': 3}
# Edge attrs non-matching! For edge  gaff, df farrant, j
# {'weight': 7} {'weight': 16}
# Edge attrs non-matching! For edge  gaff, df djilianov, d
# {'weight': 8} {'weight': 10}
# Edge attrs non-matching! For edge  gaff, df giarola, v
# {'weight': 3} {'weight': 8}
# Edge attrs non-matching! For edge  gaff, df mladenov, p
# {'weight': 1} {'weight': 2}
# Edge attrs non-matching! For edge  blomstedt, ck neale, ad
# {'weight': 57} {'weight': 26}
# Edge attrs non-matching! For edge  blomstedt, ck oliver, mj
# {'weight': 45} {'weight': 31}
# Edge attrs non-matching! For edge  blomstedt, ck farrant, j
# {'weight': 8} {'weight': 4}
# Edge attrs non-matching! For edge  blomstedt, ck fait, a
# {'weight': 2} {'weight': 1}
# Edge attrs non-matching! For edge  neale, ad oliver, mj
# {'weight': 52} {'weight': 34}
# Edge attrs non-matching! For edge  neale, ad farrant, j
# {'weight': 11} {'weight': 7}
# Edge attrs non-matching! For edge  neale, ad ligterink, w
# {'weight': 3} {'weight': 1}
# Edge attrs non-matching! For edge  neale, ad fait, a
# {'weight': 2} {'weight': 1}
# Edge attrs non-matching! For edge  neale, ad baskin, cc
# {'weight': 1} {'weight': 2}
# Edge attrs non-matching! For edge  neale, ad pacini, e
# {'weight': 1} {'weight': 2}
# Edge attrs non-matching! For edge  neale, ad baskin, jm
# {'weight': 1} {'weight': 2}
# Edge attrs non-matching! For edge  neale, ad mundree, s
# {'weight': 6} {'weight': 7}
# Edge attrs non-matching! For edge  mundree, sg lehner, a
# {'weight': 1} {'weight': 13}
# Edge attrs non-matching! For edge  mundree, sg driouich, a
# {'weight': 11} {'weight': 20}
# Edge attrs non-matching! For edge  mundree, sg cooper, k
# {'weight': 18} {'weight': 25}
# Edge attrs non-matching! For edge  mundree, sg ligterink, w
# {'weight': 4} {'weight': 6}
# Edge attrs non-matching! For edge  mundree, sg costa, mcd
# {'weight': 2} {'weight': 4}
# Edge attrs non-matching! For edge  mundree, sg burnell, am
# {'weight': 3} {'weight': 1}
# Edge attrs non-matching! For edge  mundree, sg reich, z
# {'weight': 5} {'weight': 1}
# Edge attrs non-matching! For edge  mundree, sg georgieva, k
# {'weight': 4} {'weight': 5}
# Edge attrs non-matching! For edge  whittaker, a kranner, i
# {'weight': 1} {'weight': 2}
# Edge attrs non-matching! For edge  illing, n almoguera, c
# {'weight': 3} {'weight': 4}
# Edge attrs non-matching! For edge  illing, n williams, b
# {'weight': 1} {'weight': 4}
# Edge attrs non-matching! For edge  illing, n dekkers, bjw
# {'weight': 3} {'weight': 1}
# Edge attrs non-matching! For edge  oliver, mj tuba, z
# {'weight': 39} {'weight': 101}
# Edge attrs non-matching! For edge  oliver, mj csintalan, z
# {'weight': 22} {'weight': 59}
# Edge attrs non-matching! For edge  oliver, mj dietz, kj
# {'weight': 1} {'weight': 6}
# Edge attrs non-matching! For edge  oliver, mj farrant, j
# {'weight': 19} {'weight': 14}
# Edge attrs non-matching! For edge  oliver, mj hanson, dt
# {'weight': 1} {'weight': 13}
# Edge attrs non-matching! For edge  oliver, mj liang, yq
# {'weight': 2} {'weight': 22}
# Edge attrs non-matching! For edge  oliver, mj bowker, ma
# {'weight': 22} {'weight': 1}
# Edge attrs non-matching! For edge  oliver, mj stevanovic, b
# {'weight': 13} {'weight': 8}
# Edge attrs non-matching! For edge  oliver, mj li, y
# {'weight': 16} {'weight': 3}
# Edge attrs non-matching! For edge  oliver, mj uemura, m
# {'weight': 9} {'weight': 8}
# Edge attrs non-matching! For edge  oliver, mj ligterink, w
# {'weight': 25} {'weight': 16}
# Edge attrs non-matching! For edge  oliver, mj braga, mr
# {'weight': 14} {'weight': 13}
# Edge attrs non-matching! For edge  oliver, mj fait, a
# {'weight': 6} {'weight': 5}
# Edge attrs non-matching! For edge  oliver, mj he, yk
# {'weight': 24} {'weight': 14}
# Edge attrs non-matching! For edge  oliver, mj watkins, je
# {'weight': 13} {'weight': 12}
# Edge attrs non-matching! For edge  oliver, mj gao, b
# {'weight': 1} {'weight': 28}
# Edge attrs non-matching! For edge  oliver, mj almoguera, c
# {'weight': 7} {'weight': 2}
# Edge attrs non-matching! For edge  oliver, mj prieto-dapena, p
# {'weight': 1} {'weight': 5}
# Edge attrs non-matching! For edge  oliver, mj mihailova, g
# {'weight': 1} {'weight': 14}
# Edge attrs non-matching! For edge  hilhorst, hwm deng, x
# {'weight': 6} {'weight': 5}
# Edge attrs non-matching! For edge  hilhorst, hwm wai, cm
# {'weight': 6} {'weight': 12}
# Edge attrs non-matching! For edge  hilhorst, hwm karsten, u
# {'weight': 1} {'weight': 2}
# Edge attrs non-matching! For edge  hilhorst, hwm holzinger, a
# {'weight': 3} {'weight': 5}
# Edge attrs non-matching! For edge  hilhorst, hwm stark, lr
# {'weight': 3} {'weight': 6}
# Edge attrs non-matching! For edge  hilhorst, hwm barbedo, cj
# {'weight': 8} {'weight': 1}
# Edge attrs non-matching! For edge  hilhorst, hwm tonetti, oao
# {'weight': 8} {'weight': 2}
# Edge attrs non-matching! For edge  hilhorst, hwm lahuta, lb
# {'weight': 1} {'weight': 3}
# Edge attrs non-matching! For edge  hilhorst, hwm zuther, e
# {'weight': 3} {'weight': 2}
# Edge attrs non-matching! For edge  hilhorst, hwm fernandez-marin, b
# {'weight': 3} {'weight': 6}
# Edge attrs non-matching! For edge  faria, jmr dekkers, bjw
# {'weight': 5} {'weight': 6}
# Edge attrs non-matching! For edge  faria, jmr tonetti, oao
# {'weight': 11} {'weight': 17}
# Edge attrs non-matching! For edge  phillips, j mishler, bd
# {'weight': 2} {'weight': 3}
# Edge attrs non-matching! For edge  phillips, j frank, w
# {'weight': 1} {'weight': 3}
# Edge attrs non-matching! For edge  phillips, j deng, x
# {'weight': 18} {'weight': 64}
# Edge attrs non-matching! For edge  phillips, j richter, a
# {'weight': 2} {'weight': 3}
# Edge attrs non-matching! For edge  phillips, j moyankova, d
# {'weight': 1} {'weight': 11}
# Edge attrs non-matching! For edge  phillips, j smith, me
# {'weight': 2} {'weight': 1}
# Edge attrs non-matching! For edge  phillips, j gorecki, rj
# {'weight': 2} {'weight': 3}
# Edge attrs non-matching! For edge  furini, a tuba, z
# {'weight': 2} {'weight': 1}
# Edge attrs non-matching! For edge  furini, a scott, p
# {'weight': 3} {'weight': 1}
# Edge attrs non-matching! For edge  crowe, jh potts, m
# {'weight': 20} {'weight': 7}
# Edge attrs non-matching! For edge  crowe, jh reski, r
# {'weight': 2} {'weight': 3}
# Edge attrs non-matching! For edge  crowe, jh duckett, jg
# {'weight': 2} {'weight': 1}
# Edge attrs non-matching! For edge  crowe, jh heyer, ag
# {'weight': 1} {'weight': 9}
# Edge attrs non-matching! For edge  crowe, jh zuther, e
# {'weight': 5} {'weight': 1}
# Edge attrs non-matching! For edge  crowe, jh hagemann, m
# {'weight': 6} {'weight': 7}
# Edge attrs non-matching! For edge  crowe, lm oliver, ae
# {'weight': 4} {'weight': 18}
# Edge attrs non-matching! For edge  crowe, lm macrae, th
# {'weight': 1} {'weight': 3}
# Edge attrs non-matching! For edge  wood, aj duckett, jg
# {'weight': 14} {'weight': 12}
# Edge attrs non-matching! For edge  wood, aj slate, ml
# {'weight': 1} {'weight': 8}
# Edge attrs non-matching! For edge  wood, aj wang, y
# {'weight': 13} {'weight': 8}
# Edge attrs non-matching! For edge  deng, x toneva, v
# {'weight': 17} {'weight': 8}
# Edge attrs non-matching! For edge  deng, x moore, jp
# {'weight': 25} {'weight': 10}
# Edge attrs non-matching! For edge  deng, x moyankova, d
# {'weight': 12} {'weight': 33}
# Edge attrs non-matching! For edge  deng, x gorecki, rj
# {'weight': 2} {'weight': 3}
# Edge attrs non-matching! For edge  deng, x rafudeen, ms
# {'weight': 2} {'weight': 12}
# Edge attrs non-matching! For edge  deng, x gasulla, f
# {'weight': 3} {'weight': 1}
# Edge attrs non-matching! For edge  deng, x kranner, i
# {'weight': 1} {'weight': 3}
# Edge attrs non-matching! For edge  mundree, s vanburen, r
# {'weight': 11} {'weight': 8}
# Edge attrs non-matching! For edge  mundree, s karsten, u
# {'weight': 2} {'weight': 1}
# Edge attrs non-matching! For edge  mundree, s djilianov, d
# {'weight': 5} {'weight': 3}
# Edge attrs non-matching! For edge  mundree, s mladenov, p
# {'weight': 2} {'weight': 1}
# Edge attrs non-matching! For edge  mundree, s giarola, v
# {'weight': 3} {'weight': 2}
# Edge attrs non-matching! For edge  mundree, s liu, x
# {'weight': 2} {'weight': 1}
# Edge attrs non-matching! For edge  mundree, s tuba, z
# {'weight': 3} {'weight': 1}
# Edge attrs non-matching! For edge  jordano, j toneva, v
# {'weight': 4} {'weight': 2}
# Edge attrs non-matching! For edge  jordano, j moore, jp
# {'weight': 4} {'weight': 2}
# Edge attrs non-matching! For edge  jordano, j gasulla, f
# {'weight': 3} {'weight': 1}
# Edge attrs non-matching! For edge  almoguera, c li, y
# {'weight': 3} {'weight': 1}
# Edge attrs non-matching! For edge  almoguera, c lalanne, d
# {'weight': 2} {'weight': 8}
# Edge attrs non-matching! For edge  almoguera, c li, x
# {'weight': 5} {'weight': 1}
# Edge attrs non-matching! For edge  zhang, l mishler, bd
# {'weight': 2} {'weight': 1}
# Edge attrs non-matching! For edge  zhang, l brinda, jc
# {'weight': 3} {'weight': 1}
# Edge attrs non-matching! For edge  mishler, bd csintalan, z
# {'weight': 29} {'weight': 10}
# Edge attrs non-matching! For edge  mishler, bd proctor, mcf
# {'weight': 15} {'weight': 43}
# Edge attrs non-matching! For edge  mishler, bd li, xs
# {'weight': 2} {'weight': 13}
# Edge attrs non-matching! For edge  mishler, bd yobi, a
# {'weight': 8} {'weight': 2}
# Edge attrs non-matching! For edge  mishler, bd costa, mcd
# {'weight': 12} {'weight': 3}
# Edge attrs non-matching! For edge  mishler, bd brinda, jc
# {'weight': 45} {'weight': 10}
# Edge attrs non-matching! For edge  mishler, bd wai, cm
# {'weight': 11} {'weight': 5}
# Edge attrs non-matching! For edge  mishler, bd de carvalho, rc
# {'weight': 3} {'weight': 11}
# Edge attrs non-matching! For edge  mishler, bd da silva, jm
# {'weight': 3} {'weight': 10}
# Edge attrs non-matching! For edge  mishler, bd hatanaka, r
# {'weight': 4} {'weight': 3}
# Edge attrs non-matching! For edge  tuba, z csintalan, z
# {'weight': 36} {'weight': 89}
# Edge attrs non-matching! For edge  tuba, z scott, p
# {'weight': 15} {'weight': 5}
# Edge attrs non-matching! For edge  tuba, z luttge, u
# {'weight': 3} {'weight': 1}
# Edge attrs non-matching! For edge  clegg, js browne, ja
# {'weight': 8} {'weight': 11}
# Edge attrs non-matching! For edge  clegg, js caprioli, m
# {'weight': 1} {'weight': 3}
# Edge attrs non-matching! For edge  clegg, js tablin, f
# {'weight': 7} {'weight': 1}
# Edge attrs non-matching! For edge  clegg, js altiero, t
# {'weight': 17} {'weight': 6}
# Edge attrs non-matching! For edge  clegg, js rebecchi, l
# {'weight': 21} {'weight': 7}
# Edge attrs non-matching! For edge  clegg, js schill, ro
# {'weight': 24} {'weight': 48}
# Edge attrs non-matching! For edge  clegg, js he, xm
# {'weight': 1} {'weight': 2}
# Edge attrs non-matching! For edge  clegg, js tomita, m
# {'weight': 4} {'weight': 2}
# Edge attrs non-matching! For edge  proctor, mcf beckett, rp
# {'weight': 25} {'weight': 18}
# Edge attrs non-matching! For edge  proctor, mcf satoh, k
# {'weight': 7} {'weight': 1}
# Edge attrs non-matching! For edge  proctor, mcf watkins, je
# {'weight': 13} {'weight': 14}
# Edge attrs non-matching! For edge  proctor, mcf quatrano, rs
# {'weight': 2} {'weight': 1}
# Edge attrs non-matching! For edge  smirnoff, n kashino, y
# {'weight': 6} {'weight': 1}
# Edge attrs non-matching! For edge  oldenhof, h tablin, f
# {'weight': 6} {'weight': 3}
# Edge attrs non-matching! For edge  vazquezramos, j lahuta, lb
# {'weight': 8} {'weight': 1}
# Edge attrs non-matching! For edge  jayanthi, n fu, jr
# {'weight': 1} {'weight': 4}
# Edge attrs non-matching! For edge  khoo, kc song, sq
# {'weight': 8} {'weight': 1}
# Edge attrs non-matching! For edge  tsan, fy song, sq
# {'weight': 8} {'weight': 1}
# Edge attrs non-matching! For edge  marzalina, m engelmann, f
# {'weight': 2} {'weight': 1}
# Edge attrs non-matching! For edge  bailly, c lehner, a
# {'weight': 4} {'weight': 7}
# Edge attrs non-matching! For edge  lahuta, lb lalanne, d
# {'weight': 3} {'weight': 2}
# Edge attrs non-matching! For edge  lahuta, lb wang, xf
# {'weight': 6} {'weight': 2}
# Edge attrs non-matching! For edge  lahuta, lb brenac, p
# {'weight': 25} {'weight': 3}
# Edge attrs non-matching! For edge  lahuta, lb zalewski, k
# {'weight': 23} {'weight': 12}
# Edge attrs non-matching! For edge  lahuta, lb zhang, q
# {'weight': 3} {'weight': 2}
# Edge attrs non-matching! For edge  gorecki, rj heyer, ag
# {'weight': 6} {'weight': 1}
# Edge attrs non-matching! For edge  gorecki, rj nonogaki, h
# {'weight': 3} {'weight': 2}
# Edge attrs non-matching! For edge  gorecki, rj song, sq
# {'weight': 1} {'weight': 2}
# Edge attrs non-matching! For edge  brenac, p hincha, dk
# {'weight': 3} {'weight': 2}
# Edge attrs non-matching! For edge  brenac, p nonogaki, h
# {'weight': 1} {'weight': 3}
# Edge attrs non-matching! For edge  brenac, p wang, z
# {'weight': 1} {'weight': 2}
# Edge attrs non-matching! For edge  naithani, sc varghese, b
# {'weight': 9} {'weight': 3}
# Edge attrs non-matching! For edge  sinclair, bj gibbs, ag
# {'weight': 2} {'weight': 21}
# Edge attrs non-matching! For edge  sinclair, bj kellermann, v
# {'weight': 3} {'weight': 5}
# Edge attrs non-matching! For edge  sinclair, bj overgaard, j
# {'weight': 3} {'weight': 5}
# Edge attrs non-matching! For edge  gibbs, ag aggarwal, dd
# {'weight': 29} {'weight': 2}
# Edge attrs non-matching! For edge  gibbs, ag ranga, p
# {'weight': 20} {'weight': 1}
# Edge attrs non-matching! For edge  klok, cj worland, mr
# {'weight': 9} {'weight': 14}
# Edge attrs non-matching! For edge  kohler, hr denlinger, dl
# {'weight': 8} {'weight': 9}
# Edge attrs non-matching! For edge  kohler, hr worland, mr
# {'weight': 14} {'weight': 12}
# Edge attrs non-matching! For edge  kohler, hr schill, ro
# {'weight': 34} {'weight': 36}
# Edge attrs non-matching! For edge  kohler, hr ricci, c
# {'weight': 3} {'weight': 2}
# Edge attrs non-matching! For edge  browne, ja watanabe, m
# {'weight': 5} {'weight': 3}
# Edge attrs non-matching! For edge  browne, ja okuda, t
# {'weight': 5} {'weight': 3}
# Edge attrs non-matching! For edge  browne, ja panek, ad
# {'weight': 2} {'weight': 1}
# Edge attrs non-matching! For edge  burnell, am toner, m
# {'weight': 1} {'weight': 3}
# Edge attrs non-matching! For edge  burnell, am loeschcke, v
# {'weight': 1} {'weight': 3}
# Edge attrs non-matching! For edge  denlinger, dl lopez-martinez, g
# {'weight': 26} {'weight': 73}
# Edge attrs non-matching! For edge  denlinger, dl yoder, ja
# {'weight': 6} {'weight': 3}
# Edge attrs non-matching! For edge  denlinger, dl schill, ro
# {'weight': 7} {'weight': 10}
# Edge attrs non-matching! For edge  denlinger, dl parkash, r
# {'weight': 1} {'weight': 38}
# Edge attrs non-matching! For edge  ramlov, h okuda, t
# {'weight': 11} {'weight': 15}
# Edge attrs non-matching! For edge  ramlov, h mali, b
# {'weight': 3} {'weight': 9}
# Edge attrs non-matching! For edge  lee, re benoit, jb
# {'weight': 92} {'weight': 51}
# Edge attrs non-matching! For edge  lee, re watanabe, m
# {'weight': 17} {'weight': 4}
# Edge attrs non-matching! For edge  lee, re okuda, t
# {'weight': 14} {'weight': 2}
# Edge attrs non-matching! For edge  lee, re bale, js
# {'weight': 30} {'weight': 36}
# Edge attrs non-matching! For edge  lee, re clark, ms
# {'weight': 7} {'weight': 10}
# Edge attrs non-matching! For edge  lee, re parkash, r
# {'weight': 51} {'weight': 1}
# Edge attrs non-matching! For edge  block, w somme, l
# {'weight': 3} {'weight': 9}
# Edge attrs non-matching! For edge  watanabe, m okuda, t
# {'weight': 184} {'weight': 118}
# Edge attrs non-matching! For edge  watanabe, m benoit, jb
# {'weight': 16} {'weight': 6}
# Edge attrs non-matching! For edge  watanabe, m menze, ma
# {'weight': 2} {'weight': 13}
# Edge attrs non-matching! For edge  watanabe, m hengherr, s
# {'weight': 15} {'weight': 2}
# Edge attrs non-matching! For edge  watanabe, m nakahara, y
# {'weight': 71} {'weight': 52}
# Edge attrs non-matching! For edge  watanabe, m lubzens, e
# {'weight': 5} {'weight': 6}
# Edge attrs non-matching! For edge  watanabe, m jorgensen, a
# {'weight': 7} {'weight': 1}
# Edge attrs non-matching! For edge  watanabe, m sakashita, t
# {'weight': 11} {'weight': 42}
# Edge attrs non-matching! For edge  watanabe, m horikawa, dd
# {'weight': 42} {'weight': 11}
# Edge attrs non-matching! For edge  watanabe, m cesari, m
# {'weight': 18} {'weight': 2}
# Edge attrs non-matching! For edge  parkash, r kellermann, v
# {'weight': 14} {'weight': 7}
# Edge attrs non-matching! For edge  parkash, r sorensen, jg
# {'weight': 5} {'weight': 1}
# Edge attrs non-matching! For edge  parkash, r renault, d
# {'weight': 1} {'weight': 2}
# Edge attrs non-matching! For edge  ricci, c wada, s
# {'weight': 1} {'weight': 2}
# Edge attrs non-matching! For edge  worland, mr benoit, jb
# {'weight': 23} {'weight': 32}
# Edge attrs non-matching! For edge  worland, mr lopez-martinez, g
# {'weight': 26} {'weight': 21}
# Edge attrs non-matching! For edge  worland, mr convey, p
# {'weight': 47} {'weight': 14}
# Edge attrs non-matching! For edge  worland, mr bale, js
# {'weight': 38} {'weight': 10}
# Edge attrs non-matching! For edge  wharton, da hengherr, s
# {'weight': 1} {'weight': 4}
# Edge attrs non-matching! For edge  okuda, t benoit, jb
# {'weight': 8} {'weight': 2}
# Edge attrs non-matching! For edge  okuda, t toner, m
# {'weight': 6} {'weight': 2}
# Edge attrs non-matching! For edge  okuda, t hengherr, s
# {'weight': 17} {'weight': 6}
# Edge attrs non-matching! For edge  okuda, t nakahara, y
# {'weight': 89} {'weight': 46}
# Edge attrs non-matching! For edge  okuda, t hatanaka, r
# {'weight': 15} {'weight': 2}
# Edge attrs non-matching! For edge  okuda, t jorgensen, a
# {'weight': 7} {'weight': 1}
# Edge attrs non-matching! For edge  okuda, t horikawa, dd
# {'weight': 48} {'weight': 21}
# Edge attrs non-matching! For edge  okuda, t mali, b
# {'weight': 1} {'weight': 11}
# Edge attrs non-matching! For edge  okuda, t cesari, m
# {'weight': 17} {'weight': 2}
# Edge attrs non-matching! For edge  kikawada, t thorne, mas
# {'weight': 4} {'weight': 6}
# Edge attrs non-matching! For edge  kikawada, t rebecchi, l
# {'weight': 11} {'weight': 40}
# Edge attrs non-matching! For edge  kikawada, t sakurai, m
# {'weight': 43} {'weight': 27}
# Edge attrs non-matching! For edge  kikawada, t elnitsky, ma
# {'weight': 5} {'weight': 7}
# Edge attrs non-matching! For edge  kikawada, t hatanaka, r
# {'weight': 14} {'weight': 28}
# Edge attrs non-matching! For edge  kikawada, t yoshida, y
# {'weight': 3} {'weight': 40}
# Edge attrs non-matching! For edge  kikawada, t arakawa, k
# {'weight': 7} {'weight': 1}
# Edge attrs non-matching! For edge  nelson, dr reuner, a
# {'weight': 2} {'weight': 6}
# Edge attrs non-matching! For edge  nelson, dr wada, s
# {'weight': 3} {'weight': 2}
# Edge attrs non-matching! For edge  nelson, dr kobayashi, y
# {'weight': 2} {'weight': 3}
# Edge attrs non-matching! For edge  nelson, dr frohme, m
# {'weight': 4} {'weight': 6}
# Edge attrs non-matching! For edge  hincha, dk oliver, ae
# {'weight': 12} {'weight': 37}
# Edge attrs non-matching! For edge  hincha, dk hand, sc
# {'weight': 39} {'weight': 31}
# Edge attrs non-matching! For edge  hincha, dk tapia, h
# {'weight': 1} {'weight': 5}
# Edge attrs non-matching! For edge  hincha, dk fait, a
# {'weight': 1} {'weight': 2}
# Edge attrs non-matching! For edge  oliver, ae macrae, th
# {'weight': 1} {'weight': 4}
# Edge attrs non-matching! For edge  scott, p hartung, w
# {'weight': 2} {'weight': 3}
# Edge attrs non-matching! For edge  scott, p wang, z
# {'weight': 1} {'weight': 3}
# Edge attrs non-matching! For edge  potts, m wright, dj
# {'weight': 34} {'weight': 14}
# Edge attrs non-matching! For edge  potts, m billi, d
# {'weight': 30} {'weight': 6}
# Edge attrs non-matching! For edge  guidetti, r jonsson, ki
# {'weight': 51} {'weight': 14}
# Edge attrs non-matching! For edge  guidetti, r brummer, f
# {'weight': 30} {'weight': 8}
# Edge attrs non-matching! For edge  guidetti, r cornette, r
# {'weight': 2} {'weight': 11}
# Edge attrs non-matching! For edge  guidetti, r boschetti, c
# {'weight': 16} {'weight': 13}
# Edge attrs non-matching! For edge  guidetti, r mobjerg, n
# {'weight': 22} {'weight': 7}
# Edge attrs non-matching! For edge  guidetti, r tomita, m
# {'weight': 8} {'weight': 9}
# Edge attrs non-matching! For edge  jonsson, ki tapia, h
# {'weight': 1} {'weight': 2}
# Edge attrs non-matching! For edge  jonsson, ki mobjerg, n
# {'weight': 12} {'weight': 2}
# Edge attrs non-matching! For edge  jonsson, ki horikawa, dd
# {'weight': 12} {'weight': 32}
# Edge attrs non-matching! For edge  jonsson, ki brummer, f
# {'weight': 16} {'weight': 4}
# Edge attrs non-matching! For edge  jonsson, ki hengherr, s
# {'weight': 5} {'weight': 13}
# Edge attrs non-matching! For edge  jonsson, ki dandekar, t
# {'weight': 1} {'weight': 9}
# Edge attrs non-matching! For edge  jonsson, ki caprioli, m
# {'weight': 2} {'weight': 1}
# Edge attrs non-matching! For edge  jonsson, ki cesari, m
# {'weight': 2} {'weight': 14}
# Edge attrs non-matching! For edge  helm, rf billi, d
# {'weight': 4} {'weight': 19}
# Edge attrs non-matching! For edge  helm, rf manzanera, m
# {'weight': 2} {'weight': 3}
# Edge attrs non-matching! For edge  wright, dj billi, d
# {'weight': 10} {'weight': 2}
# Edge attrs non-matching! For edge  cuming, ac reski, r
# {'weight': 6} {'weight': 9}
# Edge attrs non-matching! For edge  quatrano, rs sakurai, m
# {'weight': 1} {'weight': 4}
# Edge attrs non-matching! For edge  quatrano, rs komatsu, k
# {'weight': 1} {'weight': 14}
# Edge attrs non-matching! For edge  quatrano, rs sakata, y
# {'weight': 17} {'weight': 2}
# Edge attrs non-matching! For edge  reski, r takezawa, d
# {'weight': 5} {'weight': 3}
# Edge attrs non-matching! For edge  reski, r ligterink, w
# {'weight': 1} {'weight': 2}
# Edge attrs non-matching! For edge  acker, jp tsvetkova, nm
# {'weight': 3} {'weight': 6}
# Edge attrs non-matching! For edge  eroglu, a toner, m
# {'weight': 1} {'weight': 8}
# Edge attrs non-matching! For edge  duckett, jg moore, jp
# {'weight': 3} {'weight': 2}
# Edge attrs non-matching! For edge  beckett, rp williams, b
# {'weight': 1} {'weight': 2}
# Edge attrs non-matching! For edge  beckett, rp zhang, ym
# {'weight': 7} {'weight': 2}
# Edge attrs non-matching! For edge  dietz, kj lan, qy
# {'weight': 1} {'weight': 2}
# Edge attrs non-matching! For edge  chabrillange, n sinniah, ur
# {'weight': 4} {'weight': 1}
# Edge attrs non-matching! For edge  cooper, k driouich, a
# {'weight': 12} {'weight': 16}
# Edge attrs non-matching! For edge  cooper, k bentley, j
# {'weight': 13} {'weight': 1}
# Edge attrs non-matching! For edge  cooper, k yobi, a
# {'weight': 6} {'weight': 2}
# Edge attrs non-matching! For edge  cooper, k xu, wx
# {'weight': 5} {'weight': 2}
# Edge attrs non-matching! For edge  cooper, k wang, z
# {'weight': 5} {'weight': 3}
# Edge attrs non-matching! For edge  cooper, k brinda, jc
# {'weight': 2} {'weight': 1}
# ...
# {'weight': 11} {'weight': 5}
# Edge attrs non-matching! For edge  fernie, ar mladenov, p
# {'weight': 4} {'weight': 3}
# Edge attrs non-matching! For edge  fernie, ar wang, b
# {'weight': 2} {'weight': 3}
# Edge attrs non-matching! For edge  fernie, ar giarola, v
# {'weight': 7} {'weight': 5}
# Edge attrs non-matching! For edge  fernie, ar karsten, u
# {'weight': 2} {'weight': 1}
# Edge attrs non-matching! For edge  fernie, ar song, sq
# {'weight': 3} {'weight': 1}
# Edge attrs non-matching! For edge  fernie, ar yobi, a
# {'weight': 2} {'weight': 3}
# Edge attrs non-matching! For edge  fernie, ar dirk, lma
# {'weight': 3} {'weight': 1}
# Edge attrs non-matching! For edge  brodribb, tj sack, l
# {'weight': 3} {'weight': 1}
# Edge attrs non-matching! For edge  liang, yq gao, b
# {'weight': 3} {'weight': 13}
# Edge attrs non-matching! For edge  liang, yq zhang, j
# {'weight': 6} {'weight': 2}
# Edge attrs non-matching! For edge  zhang, dy wang, y
# {'weight': 12} {'weight': 6}
# Edge attrs non-matching! For edge  zhang, dy slate, ml
# {'weight': 2} {'weight': 3}
# Edge attrs non-matching! For edge  li, xs greenwood, jl
# {'weight': 7} {'weight': 3}
# Edge attrs non-matching! For edge  li, xs slate, ml
# {'weight': 2} {'weight': 1}
# Edge attrs non-matching! For edge  zhang, j de carvalho, rc
# {'weight': 2} {'weight': 1}
# Edge attrs non-matching! For edge  zhang, j catala, m
# {'weight': 1} {'weight': 2}
# Edge attrs non-matching! For edge  zhang, j takezawa, d
# {'weight': 3} {'weight': 2}
# Edge attrs non-matching! For edge  zhang, j zhang, yg
# {'weight': 1} {'weight': 5}
# Edge attrs non-matching! For edge  bowker, ma slate, ml
# {'weight': 2} {'weight': 5}
# Edge attrs non-matching! For edge  coe, kk zhang, ym
# {'weight': 1} {'weight': 6}
# Edge attrs non-matching! For edge  coe, kk brinda, jc
# {'weight': 7} {'weight': 21}
# Edge attrs non-matching! For edge  coe, kk zhang, yg
# {'weight': 5} {'weight': 4}
# Edge attrs non-matching! For edge  slate, ml greenwood, jl
# {'weight': 25} {'weight': 6}
# Edge attrs non-matching! For edge  brinda, jc zhang, ym
# {'weight': 3} {'weight': 8}
# Edge attrs non-matching! For edge  de carvalho, rc da silva, jm
# {'weight': 15} {'weight': 32}
# Edge attrs non-matching! For edge  catala, m del campo, em
# {'weight': 5} {'weight': 16}
# Edge attrs non-matching! For edge  catala, m gasulla, f
# {'weight': 31} {'weight': 9}
# Edge attrs non-matching! For edge  bertuzzi, s casano, lm
# {'weight': 2} {'weight': 3}
# Edge attrs non-matching! For edge  bertuzzi, s holzinger, a
# {'weight': 4} {'weight': 1}
# Edge attrs non-matching! For edge  tretiach, m casano, lm
# {'weight': 12} {'weight': 4}
# Edge attrs non-matching! For edge  carniel, fc casano, lm
# {'weight': 11} {'weight': 3}
# Edge attrs non-matching! For edge  yobi, a xu, wx
# {'weight': 5} {'weight': 4}
# Edge attrs non-matching! For edge  yobi, a toneva, v
# {'weight': 2} {'weight': 3}
# Edge attrs non-matching! For edge  yobi, a gasulla, f
# {'weight': 1} {'weight': 3}
# Edge attrs non-matching! For edge  djilianov, d mladenov, p
# {'weight': 8} {'weight': 7}
# Edge attrs non-matching! For edge  djilianov, d vanburen, r
# {'weight': 3} {'weight': 1}
# Edge attrs non-matching! For edge  djilianov, d liu, x
# {'weight': 8} {'weight': 3}
# Edge attrs non-matching! For edge  piszkiewicz, s popova, av
# {'weight': 1} {'weight': 4}
# Edge attrs non-matching! For edge  rebecchi, l altiero, t
# {'weight': 151} {'weight': 73}
# Edge attrs non-matching! For edge  rebecchi, l boothby, tc
# {'weight': 16} {'weight': 4}
# Edge attrs non-matching! For edge  rebecchi, l tomita, m
# {'weight': 12} {'weight': 10}
# Edge attrs non-matching! For edge  rebecchi, l yoshida, y
# {'weight': 11} {'weight': 13}
# Edge attrs non-matching! For edge  pielak, gj boothby, tc
# {'weight': 6} {'weight': 13}
# Edge attrs non-matching! For edge  pielak, gj horikawa, dd
# {'weight': 3} {'weight': 1}
# Edge attrs non-matching! For edge  goldstein, b menze, ma
# {'weight': 2} {'weight': 14}
# Edge attrs non-matching! For edge  tapia, h macrae, th
# {'weight': 1} {'weight': 2}
# Edge attrs non-matching! For edge  boothby, tc altiero, t
# {'weight': 10} {'weight': 3}
# Edge attrs non-matching! For edge  boothby, tc mobjerg, n
# {'weight': 2} {'weight': 4}
# Edge attrs non-matching! For edge  boothby, tc tomita, m
# {'weight': 4} {'weight': 1}
# Edge attrs non-matching! For edge  braga, mr del campo, em
# {'weight': 13} {'weight': 23}
# Edge attrs non-matching! For edge  braga, mr casano, lm
# {'weight': 23} {'weight': 13}
# Edge attrs non-matching! For edge  braga, mr figueiredo-ribeiro, rdl
# {'weight': 10} {'weight': 15}
# Edge attrs non-matching! For edge  braga, mr barbedo, cj
# {'weight': 15} {'weight': 27}
# Edge attrs non-matching! For edge  centeno, dc reich, z
# {'weight': 1} {'weight': 2}
# Edge attrs non-matching! For edge  gasulla, f kashino, y
# {'weight': 4} {'weight': 5}
# Edge attrs non-matching! For edge  gasulla, f satoh, k
# {'weight': 4} {'weight': 5}
# Edge attrs non-matching! For edge  gasulla, f wang, z
# {'weight': 1} {'weight': 3}
# Edge attrs non-matching! For edge  giarola, v vanburen, r
# {'weight': 15} {'weight': 6}
# Edge attrs non-matching! For edge  giarola, v karsten, u
# {'weight': 4} {'weight': 2}
# Edge attrs non-matching! For edge  giarola, v yang, hl
# {'weight': 2} {'weight': 1}
# Edge attrs non-matching! For edge  giarola, v liu, x
# {'weight': 7} {'weight': 6}
# Edge attrs non-matching! For edge  toner, m he, xm
# {'weight': 3} {'weight': 1}
# Edge attrs non-matching! For edge  toner, m hengherr, s
# {'weight': 2} {'weight': 1}
# Edge attrs non-matching! For edge  menze, ma gusev, o
# {'weight': 6} {'weight': 1}
# Edge attrs non-matching! For edge  menze, ma lubzens, e
# {'weight': 1} {'weight': 3}
# Edge attrs non-matching! For edge  menze, ma kikuta, s
# {'weight': 2} {'weight': 1}
# Edge attrs non-matching! For edge  hand, sc cornette, r
# {'weight': 4} {'weight': 15}
# Edge attrs non-matching! For edge  hand, sc reinhardt, r
# {'weight': 4} {'weight': 1}
# Edge attrs non-matching! For edge  hand, sc kurzchalia, tv
# {'weight': 2} {'weight': 1}
# Edge attrs non-matching! For edge  georgieva, k williams, b
# {'weight': 4} {'weight': 1}
# Edge attrs non-matching! For edge  georgieva, k moyankova, d
# {'weight': 22} {'weight': 10}
# Edge attrs non-matching! For edge  georgieva, k liu, j
# {'weight': 6} {'weight': 5}
# Edge attrs non-matching! For edge  zhang, ym wang, y
# {'weight': 4} {'weight': 10}
# Edge attrs non-matching! For edge  reich, z vanburen, r
# {'weight': 2} {'weight': 3}
# Edge attrs non-matching! For edge  hundertmark, m zuther, e
# {'weight': 10} {'weight': 16}
# Edge attrs non-matching! For edge  toneva, v wang, z
# {'weight': 1} {'weight': 6}
# Edge attrs non-matching! For edge  toneva, v zuther, e
# {'weight': 2} {'weight': 1}
# Edge attrs non-matching! For edge  koike, h yoshida, t
# {'weight': 1} {'weight': 3}
# Edge attrs non-matching! For edge  kashino, y satoh, k
# {'weight': 19} {'weight': 38}
# Edge attrs non-matching! For edge  satoh, k yoshida, t
# {'weight': 3} {'weight': 1}
# Edge attrs non-matching! For edge  zhang, p lewis, la
# {'weight': 2} {'weight': 1}
# Edge attrs non-matching! For edge  wang, j takezawa, d
# {'weight': 1} {'weight': 2}
# Edge attrs non-matching! For edge  zhang, yg zhang, y
# {'weight': 6} {'weight': 4}
# Edge attrs non-matching! For edge  karsten, u holzinger, a
# {'weight': 60} {'weight': 156}
# Edge attrs non-matching! For edge  hill, lm song, sq
# {'weight': 1} {'weight': 2}
# Edge attrs non-matching! For edge  liu, x wang, l
# {'weight': 3} {'weight': 7}
# Edge attrs non-matching! For edge  liu, x mladenov, p
# {'weight': 3} {'weight': 1}
# Edge attrs non-matching! For edge  moyankova, d williams, b
# {'weight': 5} {'weight': 3}
# Edge attrs non-matching! For edge  moyankova, d liu, j
# {'weight': 9} {'weight': 3}
# Edge attrs non-matching! For edge  wang, b qiu, bs
# {'weight': 2} {'weight': 5}
# Edge attrs non-matching! For edge  ligterink, w costa, mcd
# {'weight': 10} {'weight': 22}
# Edge attrs non-matching! For edge  ligterink, w fait, a
# {'weight': 3} {'weight': 1}
# Edge attrs non-matching! For edge  ligterink, w li, x
# {'weight': 3} {'weight': 2}
# Edge attrs non-matching! For edge  ligterink, w pereira, wvs
# {'weight': 7} {'weight': 2}
# Edge attrs non-matching! For edge  costa, mcd wai, cm
# {'weight': 7} {'weight': 2}
# Edge attrs non-matching! For edge  li, y li, x
# {'weight': 2} {'weight': 1}
# Edge attrs non-matching! For edge  chen, sl vanburen, r
# {'weight': 2} {'weight': 3}
# Edge attrs non-matching! For edge  chen, sl perry, rn
# {'weight': 1} {'weight': 2}
# Edge attrs non-matching! For edge  chen, sl qiu, bs
# {'weight': 2} {'weight': 1}
# Edge attrs non-matching! For edge  kumar, m correa, ja
# {'weight': 17} {'weight': 13}
# Edge attrs non-matching! For edge  wang, t du, yl
# {'weight': 21} {'weight': 12}
# Edge attrs non-matching! For edge  wu, l qiu, bs
# {'weight': 1} {'weight': 2}
# Edge attrs non-matching! For edge  sakurai, m kanamori, y
# {'weight': 13} {'weight': 15}
# Edge attrs non-matching! For edge  sakurai, m gusev, o
# {'weight': 4} {'weight': 15}
# Edge attrs non-matching! For edge  sakurai, m arakawa, k
# {'weight': 3} {'weight': 1}
# Edge attrs non-matching! For edge  nath, bb cornette, r
# {'weight': 9} {'weight': 1}
# Edge attrs non-matching! For edge  reinhardt, r macrae, th
# {'weight': 1} {'weight': 2}
# Edge attrs non-matching! For edge  reinhardt, r horikawa, dd
# {'weight': 2} {'weight': 3}
# Edge attrs non-matching! For edge  reinhardt, r brummer, f
# {'weight': 3} {'weight': 1}
# Edge attrs non-matching! For edge  reinhardt, r hengherr, s
# {'weight': 2} {'weight': 5}
# Edge attrs non-matching! For edge  wang, wq song, sq
# {'weight': 32} {'weight': 19}
# Edge attrs non-matching! For edge  uemura, m cornette, r
# {'weight': 6} {'weight': 5}
# Edge attrs non-matching! For edge  sakata, y furuki, t
# {'weight': 2} {'weight': 3}
# Edge attrs non-matching! For edge  ratajczak, e barbedo, cj
# {'weight': 2} {'weight': 1}
# Edge attrs non-matching! For edge  ratajczak, e li, yy
# {'weight': 2} {'weight': 1}
# Edge attrs non-matching! For edge  ratajczak, e liu, yl
# {'weight': 1} {'weight': 2}
# Edge attrs non-matching! For edge  schill, ro adams, bj
# {'weight': 1} {'weight': 2}
# Edge attrs non-matching! For edge  schill, ro lopez-martinez, g
# {'weight': 2} {'weight': 3}
# Edge attrs non-matching! For edge  schill, ro mali, b
# {'weight': 43} {'weight': 12}
# Edge attrs non-matching! For edge  reuner, a sakashita, t
# {'weight': 6} {'weight': 1}
# Edge attrs non-matching! For edge  reuner, a hayward, sal
# {'weight': 5} {'weight': 4}
# Edge attrs non-matching! For edge  brummer, f altiero, t
# {'weight': 5} {'weight': 28}
# Edge attrs non-matching! For edge  figueiredo-ribeiro, rdl barbedo, cj
# {'weight': 13} {'weight': 38}
# Edge attrs non-matching! For edge  virginia, ra adams, bj
# {'weight': 1} {'weight': 16}
# Edge attrs non-matching! For edge  wall, dh adams, bj
# {'weight': 35} {'weight': 7}
# Edge attrs non-matching! For edge  wall, dh hayward, sal
# {'weight': 5} {'weight': 1}
# Edge attrs non-matching! For edge  adams, bj hayward, sal
# {'weight': 3} {'weight': 1}
# Edge attrs non-matching! For edge  terblanche, js nyamukondiwa, c
# {'weight': 24} {'weight': 21}
# Edge attrs non-matching! For edge  terblanche, js singh, d
# {'weight': 2} {'weight': 1}
# Edge attrs non-matching! For edge  lopez-martinez, g convey, p
# {'weight': 20} {'weight': 19}
# Edge attrs non-matching! For edge  elnitsky, ma thorne, mas
# {'weight': 6} {'weight': 7}
# Edge attrs non-matching! For edge  teets, nm loeschcke, v
# {'weight': 4} {'weight': 1}
# Edge attrs non-matching! For edge  kanamori, y gusev, o
# {'weight': 1} {'weight': 33}
# Edge attrs non-matching! For edge  kanamori, y schnolzer, m
# {'weight': 2} {'weight': 3}
# Edge attrs non-matching! For edge  kanamori, y hamada, n
# {'weight': 4} {'weight': 1}
# Edge attrs non-matching! For edge  glazer, i grewal, ps
# {'weight': 13} {'weight': 5}
# Edge attrs non-matching! For edge  nakahara, y furuki, t
# {'weight': 8} {'weight': 10}
# Edge attrs non-matching! For edge  nakahara, y hengherr, s
# {'weight': 6} {'weight': 5}
# Edge attrs non-matching! For edge  nakahara, y jorgensen, a
# {'weight': 5} {'weight': 1}
# Edge attrs non-matching! For edge  nakahara, y horikawa, dd
# {'weight': 25} {'weight': 10}
# Edge attrs non-matching! For edge  nakahara, y cesari, m
# {'weight': 13} {'weight': 2}
# Edge attrs non-matching! For edge  macrae, th hengherr, s
# {'weight': 5} {'weight': 8}
# Edge attrs non-matching! For edge  hengherr, s dandekar, t
# {'weight': 2} {'weight': 18}
# Edge attrs non-matching! For edge  hansen, lt gervais, p
# {'weight': 1} {'weight': 4}
# Edge attrs non-matching! For edge  dandekar, t horikawa, dd
# {'weight': 5} {'weight': 13}
# Edge attrs non-matching! For edge  dandekar, t frohme, m
# {'weight': 22} {'weight': 8}
# Edge attrs non-matching! For edge  frohme, m kaczmarek, l
# {'weight': 14} {'weight': 1}
# Edge attrs non-matching! For edge  altiero, t kaczmarek, l
# {'weight': 5} {'weight': 31}
# Edge attrs non-matching! For edge  altiero, t kunieda, t
# {'weight': 6} {'weight': 14}
# Edge attrs non-matching! For edge  altiero, t clark, m
# {'weight': 1} {'weight': 3}
# Edge attrs non-matching! For edge  altiero, t jorgensen, a
# {'weight': 7} {'weight': 20}
# Edge attrs non-matching! For edge  altiero, t tomita, m
# {'weight': 9} {'weight': 8}
# Edge attrs non-matching! For edge  cesari, m jorgensen, a
# {'weight': 7} {'weight': 4}
# Edge attrs non-matching! For edge  cesari, m tanaka, d
# {'weight': 1} {'weight': 3}
# Edge attrs non-matching! For edge  jorgensen, a kaczmarek, l
# {'weight': 4} {'weight': 10}
# Edge attrs non-matching! For edge  jorgensen, a horikawa, dd
# {'weight': 8} {'weight': 3}
# Edge attrs non-matching! For edge  jorgensen, a kunieda, t
# {'weight': 2} {'weight': 9}
# Edge attrs non-matching! For edge  mobjerg, n wada, s
# {'weight': 1} {'weight': 5}
# Edge attrs non-matching! For edge  mobjerg, n boschetti, c
# {'weight': 4} {'weight': 3}
# Edge attrs non-matching! For edge  furuki, t cornette, r
# {'weight': 16} {'weight': 6}
# Edge attrs non-matching! For edge  rettberg, p rabbow, e
# {'weight': 12} {'weight': 18}
# Edge attrs non-matching! For edge  cornette, r tomita, m
# {'weight': 1} {'weight': 11}
# Edge attrs non-matching! For edge  kaczmarek, l kunieda, t
# {'weight': 1} {'weight': 6}
# Edge attrs non-matching! For edge  kaczmarek, l yoshida, y
# {'weight': 5} {'weight': 2}
# Edge attrs non-matching! For edge  gusev, o kikuta, s
# {'weight': 13} {'weight': 2}
# Edge attrs non-matching! For edge  gusev, o miyata, y
# {'weight': 27} {'weight': 20}
# Edge attrs non-matching! For edge  gusev, o yoshida, y
# {'weight': 22} {'weight': 19}
# Edge attrs non-matching! For edge  clark, ms loeschcke, v
# {'weight': 5} {'weight': 6}
# Edge attrs non-matching! For edge  clark, ms sorensen, jg
# {'weight': 1} {'weight': 6}
# Edge attrs non-matching! For edge  kunieda, t hamada, n
# {'weight': 7} {'weight': 1}
# Edge attrs non-matching! For edge  yoshida, y miyata, y
# {'weight': 8} {'weight': 5}
# Edge attrs non-matching! For edge  loeschcke, v sorensen, jg
# {'weight': 3} {'weight': 8}
# Edge attrs non-matching! For edge  loeschcke, v kristensen, tn
# {'weight': 3} {'weight': 7}
# Edge attrs non-matching! For edge  jeong, wj kong, fn
# {'weight': 3} {'weight': 2}
# Edge attrs non-matching! For edge  tyree, mt engelbrecht, bmj
# {'weight': 10} {'weight': 6}
# Edge attrs non-matching! For edge  manzanera, m vilchez, ji
# {'weight': 5} {'weight': 18}
# Edge attrs non-matching! For edge  overgaard, j kellermann, v
# {'weight': 3} {'weight': 7}
# Edge attrs non-matching! For edge  chakraborty, n elliott, gd
# {'weight': 2} {'weight': 1}
# Edge attrs non-matching! For edge  qiu, bs liu, w
# {'weight': 2} {'weight': 4}
# Edge attrs non-matching! For edge  jackson, ma mascarin, gm
# {'weight': 10} {'weight': 2}
# Edge attrs non-matching! For edge  convey, p bale, js
# {'weight': 31} {'weight': 17}
# Edge attrs non-matching! For edge  liu, w del campo, em
# {'weight': 2} {'weight': 1}
# Edge attrs non-matching! For edge  ranga, p aggarwal, dd
# {'weight': 14} {'weight': 7}
# Edge attrs non-matching! For edge  turner, nc du, yl
# {'weight': 10} {'weight': 24}
# Edge attrs non-matching! For edge  dow, jat davies, sa
# {'weight': 12} {'weight': 23}
# Edge attrs non-matching! For edge  shagimardanova, e deviatiiarov, r
# {'weight': 6} {'weight': 13}
# Edge attrs non-matching! For edge  rabbow, e cockell, cs
# {'weight': 4} {'weight': 2}

# %% [markdown]
# ### Co-author

# %%
nx.is_isomorphic(runs['16May2024']['co_author_network'], runs['20May2024']['co_author_network'])
# Out:
# True

# %%
nx.utils.graphs_equal(runs['16May2024']['co_author_network'], runs['20May2024']['co_author_network'])
# Out:
# False

# %%
nx.utils.nodes_equal(runs['16May2024']['co_author_network'].nodes(data=True), runs['20May2024']['co_author_network'].nodes(data=True))
# Out:
# True

# %%
nx.utils.edges_equal(runs['16May2024']['co_author_network'].edges(data=True), runs['20May2024']['co_author_network'].edges(data=True))
# Out:
# False

# %%
nx.utils.edges_equal(runs['16May2024']['co_author_network'].edges, runs['20May2024']['co_author_network'].edges)
# Out:
# True

# %% [markdown]
# The same thing is true of the co-author network.

# %%
for e1, e2, attrs in runs['16May2024']['co_author_network'].edges(data=True):
    matching_edge_attrs = runs['20May2024']['co_author_network'].get_edge_data(e1, e2)
    if attrs != matching_edge_attrs:
        print('Edge attrs non-matching! For edge ', e1, e2)
        print(attrs, matching_edge_attrs)
# Out:
# Edge attrs non-matching! For edge  csintalan, z tuba, z
# {'weight': 7} {'weight': 15}
# Edge attrs non-matching! For edge  berjak, p walters, c
# {'weight': 2} {'weight': 6}
# Edge attrs non-matching! For edge  pammenter, nw walters, c
# {'weight': 6} {'weight': 2}
# Edge attrs non-matching! For edge  bartels, d phillips, j
# {'weight': 7} {'weight': 4}
# Edge attrs non-matching! For edge  karsten, u holzinger, a
# {'weight': 5} {'weight': 11}
# Edge attrs non-matching! For edge  pritchard, hw daws, mi
# {'weight': 1} {'weight': 8}
# Edge attrs non-matching! For edge  wang, xf tan, yh
# {'weight': 4} {'weight': 2}
# Edge attrs non-matching! For edge  farrant, jm hilhorst, hwm
# {'weight': 9} {'weight': 4}
# Edge attrs non-matching! For edge  farrant, jm moore, jp
# {'weight': 12} {'weight': 2}
# Edge attrs non-matching! For edge  perera-castro, av laza, jm
# {'weight': 1} {'weight': 2}
# Edge attrs non-matching! For edge  baskin, cc baskin, jm
# {'weight': 4} {'weight': 13}
# Edge attrs non-matching! For edge  oliver, mj ligterink, w
# {'weight': 2} {'weight': 1}
# Edge attrs non-matching! For edge  oliver, mj he, yk
# {'weight': 2} {'weight': 1}
# Edge attrs non-matching! For edge  ligterink, w pereira, wvs
# {'weight': 2} {'weight': 1}
# Edge attrs non-matching! For edge  kohler, hr schill, ro
# {'weight': 1} {'weight': 2}
# Edge attrs non-matching! For edge  blomstedt, ck neale, ad
# {'weight': 9} {'weight': 1}
# Edge attrs non-matching! For edge  gaff, df hamill, jd
# {'weight': 2} {'weight': 9}
# Edge attrs non-matching! For edge  sgro, cm hoffmann, aa
# {'weight': 2} {'weight': 7}
# Edge attrs non-matching! For edge  hincha, dk oliver, ae
# {'weight': 1} {'weight': 6}
# Edge attrs non-matching! For edge  barreno, e catala, m
# {'weight': 4} {'weight': 8}
# Edge attrs non-matching! For edge  holmstrup, m loeschcke, v
# {'weight': 1} {'weight': 5}
# Edge attrs non-matching! For edge  holmstrup, m overgaard, j
# {'weight': 4} {'weight': 1}
# Edge attrs non-matching! For edge  holmstrup, m sorensen, jg
# {'weight': 1} {'weight': 6}
# Edge attrs non-matching! For edge  gusev, o kikuta, s
# {'weight': 4} {'weight': 2}
# Edge attrs non-matching! For edge  kikawada, t sakurai, m
# {'weight': 10} {'weight': 4}
# Edge attrs non-matching! For edge  terblanche, js nyamukondiwa, c
# {'weight': 3} {'weight': 1}
# Edge attrs non-matching! For edge  gorecki, rj obendorf, rl
# {'weight': 2} {'weight': 6}
# Edge attrs non-matching! For edge  lahuta, lb horbowicz, m
# {'weight': 2} {'weight': 9}
# Edge attrs non-matching! For edge  lahuta, lb zalewski, k
# {'weight': 6} {'weight': 2}
# Edge attrs non-matching! For edge  wolkers, wf oldenhof, h
# {'weight': 14} {'weight': 21}
# Edge attrs non-matching! For edge  wolkers, wf oliver, ae
# {'weight': 4} {'weight': 1}
# Edge attrs non-matching! For edge  crowe, jh madin, kac
# {'weight': 7} {'weight': 2}
# Edge attrs non-matching! For edge  crowe, jh loomis, sh
# {'weight': 6} {'weight': 4}
# Edge attrs non-matching! For edge  crowe, jh potts, m
# {'weight': 3} {'weight': 1}
# Edge attrs non-matching! For edge  crowe, lm oliver, ae
# {'weight': 2} {'weight': 6}
# Edge attrs non-matching! For edge  barbedo, cj figueiredo-ribeiro, rdl
# {'weight': 4} {'weight': 5}
# Edge attrs non-matching! For edge  jonsson, ki guidetti, r
# {'weight': 2} {'weight': 1}
# Edge attrs non-matching! For edge  convey, p bale, js
# {'weight': 8} {'weight': 6}
# Edge attrs non-matching! For edge  convey, p worland, mr
# {'weight': 7} {'weight': 4}
# Edge attrs non-matching! For edge  tunnacliffe, a burnell, am
# {'weight': 1} {'weight': 6}
# Edge attrs non-matching! For edge  tunnacliffe, a manzanera, m
# {'weight': 5} {'weight': 2}
# Edge attrs non-matching! For edge  vu, bl satour, p
# {'weight': 2} {'weight': 3}
# Edge attrs non-matching! For edge  engelbrecht, bmj tyree, mt
# {'weight': 5} {'weight': 2}
# Edge attrs non-matching! For edge  loeschcke, v kristensen, tn
# {'weight': 4} {'weight': 6}
# Edge attrs non-matching! For edge  worland, mr bale, js
# {'weight': 8} {'weight': 5}
# Edge attrs non-matching! For edge  lehner, a bailly, c
# {'weight': 1} {'weight': 4}
# Edge attrs non-matching! For edge  sakurai, m arakawa, k
# {'weight': 2} {'weight': 1}
# Edge attrs non-matching! For edge  faria, jmr tonetti, oao
# {'weight': 4} {'weight': 6}
# Edge attrs non-matching! For edge  watanabe, m horikawa, dd
# {'weight': 6} {'weight': 3}
# Edge attrs non-matching! For edge  watanabe, m sakashita, t
# {'weight': 4} {'weight': 6}
# Edge attrs non-matching! For edge  watanabe, m nakahara, y
# {'weight': 12} {'weight': 5}
# Edge attrs non-matching! For edge  rebecchi, l altiero, t
# {'weight': 16} {'weight': 12}
# Edge attrs non-matching! For edge  chen, m zhang, w
# {'weight': 5} {'weight': 1}
# Edge attrs non-matching! For edge  phillips, j deng, x
# {'weight': 2} {'weight': 7}
# Edge attrs non-matching! For edge  del campo, em braga, mr
# {'weight': 1} {'weight': 3}
# Edge attrs non-matching! For edge  sun, wq leopold, ac
# {'weight': 1} {'weight': 5}
# Edge attrs non-matching! For edge  satoh, k kashino, y
# {'weight': 9} {'weight': 10}
# Edge attrs non-matching! For edge  schill, ro mali, b
# {'weight': 9} {'weight': 1}
# Edge attrs non-matching! For edge  hengherr, s dandekar, t
# {'weight': 1} {'weight': 2}
# Edge attrs non-matching! For edge  toneva, v fernie, ar
# {'weight': 2} {'weight': 3}
# Edge attrs non-matching! For edge  aggarwal, dd ranga, p
# {'weight': 6} {'weight': 1}
# Edge attrs non-matching! For edge  zhang, ym zhang, cx
# {'weight': 1} {'weight': 2}
# Edge attrs non-matching! For edge  slate, ml greenwood, jl
# {'weight': 4} {'weight': 2}
# Edge attrs non-matching! For edge  brinda, jc coe, kk
# {'weight': 1} {'weight': 3}
# Edge attrs non-matching! For edge  brinda, jc mishler, bd
# {'weight': 3} {'weight': 2}
# Edge attrs non-matching! For edge  cushman, jc yobi, a
# {'weight': 5} {'weight': 4}
# Edge attrs non-matching! For edge  wall, dh adams, bj
# {'weight': 8} {'weight': 3}
# Edge attrs non-matching! For edge  quatrano, rs sakata, y
# {'weight': 3} {'weight': 2}
# Edge attrs non-matching! For edge  yoshida, y miyata, y
# {'weight': 3} {'weight': 2}
# Edge attrs non-matching! For edge  horikawa, dd rothschild, lj
# {'weight': 1} {'weight': 3}
# Edge attrs non-matching! For edge  horikawa, dd nakahara, y
# {'weight': 6} {'weight': 2}
# Edge attrs non-matching! For edge  zhang, yg zhang, y
# {'weight': 3} {'weight': 2}
# Edge attrs non-matching! For edge  rabbow, e cockell, cs
# {'weight': 4} {'weight': 1}
# Edge attrs non-matching! For edge  brodribb, tj nadal, m
# {'weight': 1} {'weight': 2}
# Edge attrs non-matching! For edge  chakraborty, n elliott, gd
# {'weight': 3} {'weight': 1}
# Edge attrs non-matching! For edge  walters, c hill, lm
# {'weight': 1} {'weight': 6}
# Edge attrs non-matching! For edge  kunieda, t hamada, n
# {'weight': 2} {'weight': 1}
# Edge attrs non-matching! For edge  furuki, t nakahara, y
# {'weight': 1} {'weight': 2}
# Edge attrs non-matching! For edge  frohme, m dandekar, t
# {'weight': 9} {'weight': 3}
# Edge attrs non-matching! For edge  gao, b liang, yq
# {'weight': 3} {'weight': 5}
# Edge attrs non-matching! For edge  davies, sa dow, jat
# {'weight': 5} {'weight': 7}
# Edge attrs non-matching! For edge  madin, kac loomis, sh
# {'weight': 4} {'weight': 1}
# Edge attrs non-matching! For edge  wang, t du, yl
# {'weight': 5} {'weight': 2}
# Edge attrs non-matching! For edge  vilchez, ji manzanera, m
# {'weight': 1} {'weight': 7}

# %% [markdown]
# This is certainly starting to look more buggy than simply indeterminate. However, I would not expect this level of differences to affect every non-zero score in the dataset, which it seems to be doing. So we need to track down the source of these differences, and if it's a bug, fix it and then check once again for non-determinism.
